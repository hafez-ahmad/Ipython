# %%
import pandas as pd
import numpy as np

# %%
x=np.array([1,2,3])
y=x*2

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf

# %%
import scipy

# %%
1+2
# Out:
# 3

# %%
sess=tf.InteractiveSession()

# %%
a=tf.constant(2)

# %%
b=tf.constant(44)

# %%
c=a+b
c.eval()
# Out:
# 46

# %%
tf.truncated_normal([3,3,3],mean=0.0,stddev=1.0)
# Out:
# <tf.Tensor 'truncated_normal:0' shape=(3, 3, 3) dtype=float32>

# %%
# !pip install pyspark
# Out:
# ...
#     100% |████████████████████████████████| 211.9MB 102kB/s
# ...
#     100% |████████████████████████████████| 204kB 25.1MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/be/7d/34/cd3cfbc75d8b6b6ae0658e5425348560b86d187fe3e53832cc
# Successfully built pyspark
# ...

# %%
import pyspark

# %%
# !pip install wordcloud
# Out:
# ...
#     100% |████████████████████████████████| 368kB 7.3MB/s
# ...

# %%
import wordcloud

# %%
text="Let’s start this PyTorch Tutorial blog by establishing a fact that Deep Learning is something that is being used by everyone today, ranging from Virtual Assistance to getting recommendations while shopping! With newer tools emerging to make better use of Deep Learning, programming and implementation have become easier"

# %%
text
# Out:
# 'Let’s start this PyTorch Tutorial blog by establishing a fact that Deep Learning is something that is being used by everyone today, ranging from Virtual Assistance to getting recommendations while shopping! With newer tools emerging to make better use of Deep Learning, programming and implementation have become easier'

# %%
from wordcloud import WordCloud

# %%
word=WordCloud().generate(text)

# %%
plt.imshow(word,interpolation='bilinear')

# %%
import nltk

# %%
import seaborn as sb

# %%
tips=sb.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.regplot(x='total_bill',y='tip',data=tips)

# %%
sb.lmplot(x='size',y='tip',data=tips)

# %%
tips['big_tip']=(tips.tip/tips.total_bill)>0.20

# %%
sb.lmplot(x='total_bill',y='big_tip',data=tips,logistic=True,y_jitter=0.03)

# %%
sb.lmplot(x='total_bill',y='tip',hue='smoker',data=tips)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  big_tip
# 0       16.99  1.01  Female     No  Sun  Dinner     2    False
# 1       10.34  1.66    Male     No  Sun  Dinner     3    False
# 2       21.01  3.50    Male     No  Sun  Dinner     3    False
# 3       23.68  3.31    Male     No  Sun  Dinner     2    False
# 4       24.59  3.61  Female     No  Sun  Dinner     4    False

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sb.lmplot(x='total_bill',y='tip',hue='smoker',col='time',data=tips)

# %%
sb.lmplot(x='total_bill',y='tip',hue='smoker',col='time',row='sex',data=tips)

# %%
sb.pairplot(tips,x_vars=['total_bill','size'],y_vars=['tip'],hue='smoker',kind='reg')

# %%
import statsmodels

# %%
x=tips['size'].values

# %%
type(x)
# Out:
# numpy.ndarray

# %%
xv=x.ravel()

# %%
xv.shape
# Out:
# (244,)

# %%
y=xv*2

# %%
y.shape
# Out:
# (244,)

# %%
import statsmodels.formula.api as smf

# %%
reg=smf.ols('total_bill ~ tip',data=tips).fit()

# %%
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             total_bill   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     203.4
# Date:                Tue, 30 Oct 2018   Prob (F-statistic):           6.69e-34
# Time:                        18:29:48   Log-Likelihood:                -804.77
# No. Observations:                 244   AIC:                             1614.
# Df Residuals:                     242   BIC:                             1621.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.7503      1.006      6.707      0.000       4.768       8.733
# ...

# %%
predvalues=reg.fittedvalues.copy()

# %%
reg.rsquared
# Out:
# 0.45661658635167635
